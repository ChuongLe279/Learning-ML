# %%
import numpy as np

# %%
class Node:
    def __init__(self, value=None, left=None, right=None, threshold=None):
        self.value = value
        self.left = left
        self.right = right
        self.threshold = threshold

# %%
class DecisionTree:
    def __init__(self, min_sample_split=5, max_depth=10,n_features=None):
        self.min_sample_split = min_sample_split
        self.max_depth = max_depth
        self.n_features = n_features
        self.root = None
    
    #def fit(self, X, y):
